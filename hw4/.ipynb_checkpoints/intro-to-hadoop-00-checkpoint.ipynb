# %% [markdown]
# # Introduction to Hadoop MapReduce on Palmetto

# %% [markdown]
# Run the following commands to check that your `.jhubrc` file contains the correct modules

# %%
# !cat ~/.jhubrc
# !cat ~/.bashrc
# Out:
# # For CPSC6770
# module load openmpi/1.10.3-gcc/5.4.0-cuda9_2
#
# # For TensorFlow
# #module load cuda-toolkit/9.0.176
# #module load cuDNN/9.0v7
#
# module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1
# # .bashrc
#
# if [ -f /etc/bashrc ]; then
# 	. /etc/bashrc
# fi
#
# # Uncomment the following line if you don't like systemctl's auto-paging feature:
# # export SYSTEMD_PAGER=
#
# # User specific aliases and functions
# module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1
#
# # MPI
# module load openmpi/1.10.3-gcc/5.4.0-cuda9_2
#
# # Python
# module load anaconda3/5.1.0-gcc
#
# # CUDA
# module load cuda/10.2.89-gcc/8.3.1
#
# # spack
# source ~/software/spack/share/spack/setup-env.sh

# %% [markdown]
# If the modules are not there

# %%
! echo "module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1" >> ~/.jhubrc
! echo "module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1" >> ~/.bashrc

# %% [markdown]
# Check again

# %%
# !cat ~/.jhubrc
# !cat ~/.bashrc
# Out:
# # For CPSC6770
# module load openmpi/1.10.3-gcc/5.4.0-cuda9_2
#
# # For TensorFlow
# #module load cuda-toolkit/9.0.176
# #module load cuDNN/9.0v7
#
# module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1
# module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1
# # .bashrc
#
# if [ -f /etc/bashrc ]; then
# 	. /etc/bashrc
# fi
#
# # Uncomment the following line if you don't like systemctl's auto-paging feature:
# # export SYSTEMD_PAGER=
#
# # User specific aliases and functions
# module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1
#
# # MPI
# module load openmpi/1.10.3-gcc/5.4.0-cuda9_2
#
# # Python
# module load anaconda3/5.1.0-gcc
#
# # CUDA
# module load cuda/10.2.89-gcc/8.3.1
#
# # spack
# source ~/software/spack/share/spack/setup-env.sh
# module load openjdk/1.8.0_222-b10-gcc/8.3.1 hadoop/3.2.1-gcc/8.3.1

# %% [markdown]
# ### Restart the JupyterLab server

# %% [markdown]
# ## Launch the cluster

# %%
# !./init_hadoop.sh
# Out:
# Namenode hostname node2055.palmetto.clemson.edu
# Check temp dir creations
# node0284.palmetto.clemson.edu
# Warning: Permanently added 'node0284.palmetto.clemson.edu,10.125.2.25' (RSA) to the list of known hosts.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# node0284.palmetto.clemson.edu
# total 0
# -rw-r--r-- 1 jin6 cuuser 0 Oct 29 10:02 test
# Connection to node0284.palmetto.clemson.edu closed.
# node0291.palmetto.clemson.edu
# Warning: Permanently added 'node0291.palmetto.clemson.edu,10.125.2.32' (RSA) to the list of known hosts.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# node0291.palmetto.clemson.edu
# total 0
# -rw-r--r-- 1 jin6 cuuser 0 Oct 29 10:02 test
# Connection to node0291.palmetto.clemson.edu closed.
# node0382.palmetto.clemson.edu
# Warning: Permanently added 'node0382.palmetto.clemson.edu,10.125.2.123' (RSA) to the list of known hosts.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# node0382.palmetto.clemson.edu
# total 0
# -rw-r--r-- 1 jin6 cuuser 0 Oct 29 10:02 test
# Connection to node0382.palmetto.clemson.edu closed.
# node2055.palmetto.clemson.edu
# Warning: Permanently added 'node2055.palmetto.clemson.edu,10.125.10.199' (RSA) to the list of known hosts.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# node2055.palmetto.clemson.edu
# total 0
# drwxr-xr-x 3 jin6 cuuser 25 Oct 29 09:07 npm-3586163-2d4ca674
# -rw-r--r-- 1 jin6 cuuser  0 Oct 29 10:02 test
# Connection to node2055.palmetto.clemson.edu closed.
# HADOOP_ROOT: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4
# JAVA_HOME: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/openjdk-1.8.0_222-b10-ui6ldtk7sly7izptgo3yptahiqabz4fd
# NameNode is: node2055.palmetto.clemson.edu
# Resource Manager Node is: node2055.palmetto.clemson.edu
# NameNode
#     Identifier: node2055.palmetto.clemson.edu
#     Services: NameNode, JobHistoryServer, HMaster
#
# Resource Manager Node
#     Identifier: node2055.palmetto.clemson.edu
#     Services: Resource Manager, Secondary NameNode
#
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0291.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0291.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0291.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0291.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0291.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0382.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0382.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0382.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0382.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node0382.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node2055.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node2055.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node2055.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node2055.palmetto.clemson.edu closed.
#
# The following have been reloaded with a version change:
#   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
#
# Connection to node2055.palmetto.clemson.edu closed.
# Begin launching Hadoop cluster ...
# 2020-10-29 10:03:24,638 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = node2055.palmetto.clemson.edu/10.125.10.199
# STARTUP_MSG:   args = [-format, -force]
# STARTUP_MSG:   version = 3.2.1
# STARTUP_MSG:   classpath = /home/jin6/hadoop_palmetto/config:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerby-util-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerby-xdr-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/commons-net-3.6.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/commons-beanutils-1.9.3.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/snappy-java-1.0.5.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/jul-to-slf4j-1.7.25.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerb-server-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/commons-cli-1.2.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/jetty-xml-9.3.24.v20180605.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerb-simplekdc-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/zookeeper-3.4.13.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/jersey-json-1.19.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/guava-27.0-jre.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/javax.servlet-api-3.1.0.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerby-asn1-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/log4j-1.2.17.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/jetty-http-9.3.24.v20180605.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerb-admin-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/jsch-0.1.54.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerb-common-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/hadoop-annotations-3.2.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/animal-sniffer-annotations-1.17.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerb-crypto-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/woodstox-core-5.0.3.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/kerb-core-1.0.1.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/jackson-annotations-2.9.8.jar:/software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/common/lib/jetty-servlet-9.3.24.v20180605.jar:/software/spackages/linux ...
# STARTUP_MSG:   build = https://gitbox.apache.org/repos/asf/hadoop.git -r b3cbbb467e22ea829b3808f4b7b01d07e0bf3842; compiled by 'rohithsharmaks' on 2019-09-10T15:56Z
# STARTUP_MSG:   java = 1.8.0_222
# ************************************************************/
# 2020-10-29 10:03:24,658 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2020-10-29 10:03:24,844 INFO namenode.NameNode: createNameNode [-format, -force]
# 2020-10-29 10:03:25,003 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Formatting using clusterid: CID-9eeddeeb-44c1-499d-8cd3-78edd7561065
# 2020-10-29 10:03:25,513 INFO namenode.FSEditLog: Edit logging is async:true
# 2020-10-29 10:03:25,529 INFO namenode.FSNamesystem: KeyProvider: null
# 2020-10-29 10:03:25,531 INFO namenode.FSNamesystem: fsLock is fair: true
# 2020-10-29 10:03:25,532 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2020-10-29 10:03:25,545 INFO namenode.FSNamesystem: fsOwner             = jin6 (auth:SIMPLE)
# 2020-10-29 10:03:25,545 INFO namenode.FSNamesystem: supergroup          = supergroup
# 2020-10-29 10:03:25,545 INFO namenode.FSNamesystem: isPermissionEnabled = false
# 2020-10-29 10:03:25,545 INFO namenode.FSNamesystem: HA Enabled: false
# 2020-10-29 10:03:25,596 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2020-10-29 10:03:25,607 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit: configured=1000, counted=60, effected=1000
# 2020-10-29 10:03:25,607 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2020-10-29 10:03:25,612 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2020-10-29 10:03:25,612 INFO blockmanagement.BlockManager: The block deletion will start around 2020 Oct 29 10:03:25
# 2020-10-29 10:03:25,613 INFO util.GSet: Computing capacity for map BlocksMap
# 2020-10-29 10:03:25,614 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 10:03:25,615 INFO util.GSet: 2.0% max memory 512 MB = 10.2 MB
# 2020-10-29 10:03:25,615 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2020-10-29 10:03:25,652 INFO blockmanagement.BlockManager: Storage policy satisfier is disabled
# 2020-10-29 10:03:25,652 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2020-10-29 10:03:25,660 INFO Configuration.deprecation: No unit for dfs.namenode.safemode.extension(30000) assuming MILLISECONDS
# 2020-10-29 10:03:25,660 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.9990000128746033
# 2020-10-29 10:03:25,660 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2020-10-29 10:03:25,660 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2020-10-29 10:03:25,660 INFO blockmanagement.BlockManager: defaultReplication         = 3
# 2020-10-29 10:03:25,661 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2020-10-29 10:03:25,661 INFO blockmanagement.BlockManager: minReplication             = 1
# 2020-10-29 10:03:25,661 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2020-10-29 10:03:25,661 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2020-10-29 10:03:25,661 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2020-10-29 10:03:25,661 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2020-10-29 10:03:25,695 INFO namenode.FSDirectory: GLOBAL serial map: bits=29 maxEntries=536870911
# 2020-10-29 10:03:25,695 INFO namenode.FSDirectory: USER serial map: bits=24 maxEntries=16777215
# 2020-10-29 10:03:25,695 INFO namenode.FSDirectory: GROUP serial map: bits=24 maxEntries=16777215
# 2020-10-29 10:03:25,695 INFO namenode.FSDirectory: XATTR serial map: bits=24 maxEntries=16777215
# 2020-10-29 10:03:25,709 INFO util.GSet: Computing capacity for map INodeMap
# 2020-10-29 10:03:25,709 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 10:03:25,710 INFO util.GSet: 1.0% max memory 512 MB = 5.1 MB
# 2020-10-29 10:03:25,710 INFO util.GSet: capacity      = 2^19 = 524288 entries
# 2020-10-29 10:03:25,711 INFO namenode.FSDirectory: ACLs enabled? false
# 2020-10-29 10:03:25,711 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2020-10-29 10:03:25,711 INFO namenode.FSDirectory: XAttrs enabled? true
# 2020-10-29 10:03:25,711 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2020-10-29 10:03:25,716 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true, maxSnapshotLimit: 65536
# 2020-10-29 10:03:25,717 INFO snapshot.SnapshotManager: SkipList is disabled
# 2020-10-29 10:03:25,721 INFO util.GSet: Computing capacity for map cachedBlocks
# 2020-10-29 10:03:25,721 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 10:03:25,721 INFO util.GSet: 0.25% max memory 512 MB = 1.3 MB
# 2020-10-29 10:03:25,721 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2020-10-29 10:03:25,731 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2020-10-29 10:03:25,731 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2020-10-29 10:03:25,731 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2020-10-29 10:03:25,736 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2020-10-29 10:03:25,736 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2020-10-29 10:03:25,738 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2020-10-29 10:03:25,738 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 10:03:25,738 INFO util.GSet: 0.029999999329447746% max memory 512 MB = 157.3 KB
# 2020-10-29 10:03:25,738 INFO util.GSet: capacity      = 2^14 = 16384 entries
# 2020-10-29 10:03:25,775 INFO namenode.FSImage: Allocated new BlockPoolId: BP-509674301-10.125.10.199-1603980205761
# 2020-10-29 10:03:25,785 INFO common.Storage: Storage directory /local_scratch/pbs.788151.pbs02/hadoop/tmp/dfs/name has been successfully formatted.
# 2020-10-29 10:03:25,823 INFO namenode.FSImageFormatProtobuf: Saving image file /local_scratch/pbs.788151.pbs02/hadoop/tmp/dfs/name/current/fsimage.ckpt_0000000000000000000 using no compression
# 2020-10-29 10:03:25,938 INFO namenode.FSImageFormatProtobuf: Image file /local_scratch/pbs.788151.pbs02/hadoop/tmp/dfs/name/current/fsimage.ckpt_0000000000000000000 of size 399 bytes saved in 0 seconds .
# 2020-10-29 10:03:25,948 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2020-10-29 10:03:25,953 INFO namenode.FSImage: FSImageSaver clean checkpoint: txid=0 when meet shutdown.
# 2020-10-29 10:03:25,953 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at node2055.palmetto.clemson.edu/10.125.10.199
# ************************************************************/
#
# real	0m4.529s
# user	0m4.211s
# sys	0m0.422s
# + /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/sbin/start-dfs.sh --config /home/jin6/hadoop_palmetto/config
# Starting namenodes on [node2055.palmetto.clemson.edu]
# node2055.palmetto.clemson.edu:
# node2055.palmetto.clemson.edu: The following have been reloaded with a version change:
# node2055.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node2055.palmetto.clemson.edu:
# Starting datanodes
# node2055.palmetto.clemson.edu:
# node2055.palmetto.clemson.edu: The following have been reloaded with a version change:
# node2055.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node2055.palmetto.clemson.edu:
# node0291.palmetto.clemson.edu:
# node0291.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0291.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0291.palmetto.clemson.edu:
# node0382.palmetto.clemson.edu:
# node0382.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0382.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0382.palmetto.clemson.edu:
# Starting secondary namenodes [node2055.palmetto.clemson.edu]
# node2055.palmetto.clemson.edu:
# node2055.palmetto.clemson.edu: The following have been reloaded with a version change:
# node2055.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node2055.palmetto.clemson.edu:
# 2020-10-29 10:03:47,387 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#
# real	0m21.543s
# user	0m10.927s
# sys	0m1.077s
# + /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/sbin/start-yarn.sh --config /home/jin6/hadoop_palmetto/config
# WARNING: YARN_CONF_DIR has been replaced by HADOOP_CONF_DIR. Using value of YARN_CONF_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# Starting resourcemanager
# WARNING: YARN_CONF_DIR has been replaced by HADOOP_CONF_DIR. Using value of YARN_CONF_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# Starting nodemanagers
# WARNING: YARN_CONF_DIR has been replaced by HADOOP_CONF_DIR. Using value of YARN_CONF_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# node2055.palmetto.clemson.edu:
# node2055.palmetto.clemson.edu: The following have been reloaded with a version change:
# node2055.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node2055.palmetto.clemson.edu:
# node0291.palmetto.clemson.edu:
# node0291.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0291.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0291.palmetto.clemson.edu:
# node0382.palmetto.clemson.edu:
# node0382.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0382.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0382.palmetto.clemson.edu:
#
# real	0m11.659s
# user	0m5.960s
# sys	0m0.692s
# + echo 'Waiting for datanodes to launch ...'
# Waiting for datanodes to launch ...
# + sleep 10
# + /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/bin/hdfs --config /home/jin6/hadoop_palmetto/config dfsadmin -report
# 2020-10-29 10:04:10,873 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Configured Capacity: 2992130494464 (2.72 TB)
# Present Capacity: 2950060433408 (2.68 TB)
# DFS Remaining: 2950060421120 (2.68 TB)
# DFS Used: 12288 (12 KB)
# DFS Used%: 0.00%
# Replicated Blocks:
# 	Under replicated blocks: 0
# 	Blocks with corrupt replicas: 0
# 	Missing blocks: 0
# 	Missing blocks (with replication factor 1): 0
# 	Low redundancy blocks with highest priority to recover: 0
# 	Pending deletion blocks: 0
# Erasure Coded Block Groups:
# 	Low redundancy block groups: 0
# 	Block groups with corrupt internal blocks: 0
# 	Missing block groups: 0
# 	Low redundancy blocks with highest priority to recover: 0
# 	Pending deletion blocks: 0
#
# -------------------------------------------------
# Live datanodes (3):
#
# Name: 10.125.10.199:9866 (node2055.palmetto.clemson.edu)
# Hostname: node2055.palmetto.clemson.edu
# Decommission Status : Normal
# Configured Capacity: 2943833608192 (2.68 TB)
# DFS Used: 4096 (4 KB)
# Non DFS Used: 20567453696 (19.15 GB)
# DFS Remaining: 2923266150400 (2.66 TB)
# DFS Used%: 0.00%
# DFS Remaining%: 99.30%
# Configured Cache Capacity: 0 (0 B)
# Cache Used: 0 (0 B)
# Cache Remaining: 0 (0 B)
# Cache Used%: 100.00%
# Cache Remaining%: 0.00%
# Xceivers: 1
# Last contact: Thu Oct 29 10:04:10 EDT 2020
# Last Block Report: Thu Oct 29 10:03:37 EDT 2020
# Num of Blocks: 0
#
#
# Name: 10.125.2.123:9866 (node0382.palmetto.clemson.edu)
# Hostname: node0382.palmetto.clemson.edu
# Decommission Status : Normal
# Configured Capacity: 24148443136 (22.49 GB)
# DFS Used: 4096 (4 KB)
# Non DFS Used: 9230274560 (8.60 GB)
# DFS Remaining: 14918164480 (13.89 GB)
# DFS Used%: 0.00%
# DFS Remaining%: 61.78%
# Configured Cache Capacity: 0 (0 B)
# Cache Used: 0 (0 B)
# Cache Remaining: 0 (0 B)
# Cache Used%: 100.00%
# Cache Remaining%: 0.00%
# Xceivers: 1
# Last contact: Thu Oct 29 10:04:09 EDT 2020
# Last Block Report: Thu Oct 29 10:03:42 EDT 2020
# Num of Blocks: 0
#
#
# Name: 10.125.2.32:9866 (node0291.palmetto.clemson.edu)
# Hostname: node0291.palmetto.clemson.edu
# Decommission Status : Normal
# Configured Capacity: 24148443136 (22.49 GB)
# DFS Used: 4096 (4 KB)
# Non DFS Used: 12272332800 (11.43 GB)
# DFS Remaining: 11876106240 (11.06 GB)
# DFS Used%: 0.00%
# DFS Remaining%: 49.18%
# Configured Cache Capacity: 0 (0 B)
# Cache Used: 0 (0 B)
# Cache Remaining: 0 (0 B)
# Cache Used%: 100.00%
# Cache Remaining%: 0.00%
# Xceivers: 1
# Last contact: Thu Oct 29 10:04:09 EDT 2020
# Last Block Report: Thu Oct 29 10:03:42 EDT 2020
# Num of Blocks: 0
#
#
#
# real	0m2.806s
# user	0m3.773s
# sys	0m0.329s

# %% [markdown]
# ## Test the cluster

# %%
# !./test_hadoop.sh
# Out:
# + echo HADOOP_ROOT: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4
# HADOOP_ROOT: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4
# + echo JAVA_HOME: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/openjdk-1.8.0_222-b10-ui6ldtk7sly7izptgo3yptahiqabz4fd
# JAVA_HOME: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/openjdk-1.8.0_222-b10-ui6ldtk7sly7izptgo3yptahiqabz4fd
# + hdfs --config /home/jin6/hadoop_palmetto/config dfsadmin -report
# 2020-09-02 11:17:10,221 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Configured Capacity: 555240206336 (517.11 GB)
# Present Capacity: 540482064384 (503.36 GB)
# DFS Remaining: 540482052096 (503.36 GB)
# DFS Used: 12288 (12 KB)
# DFS Used%: 0.00%
# Replicated Blocks:
# 	Under replicated blocks: 0
# 	Blocks with corrupt replicas: 0
# 	Missing blocks: 0
# 	Missing blocks (with replication factor 1): 0
# 	Low redundancy blocks with highest priority to recover: 0
# 	Pending deletion blocks: 0
# Erasure Coded Block Groups:
# 	Low redundancy block groups: 0
# 	Block groups with corrupt internal blocks: 0
# 	Missing block groups: 0
# 	Low redundancy blocks with highest priority to recover: 0
# 	Pending deletion blocks: 0
#
# -------------------------------------------------
# Live datanodes (3):
#
# Name: 10.125.10.159:9866 (node2022.palmetto.clemson.edu)
# Hostname: node2022.palmetto.clemson.edu
# Decommission Status : Normal
# Configured Capacity: 189820112896 (176.78 GB)
# DFS Used: 4096 (4 KB)
# Non DFS Used: 4313829376 (4.02 GB)
# DFS Remaining: 185506279424 (172.77 GB)
# DFS Used%: 0.00%
# DFS Remaining%: 97.73%
# Configured Cache Capacity: 0 (0 B)
# Cache Used: 0 (0 B)
# Cache Remaining: 0 (0 B)
# Cache Used%: 100.00%
# Cache Remaining%: 0.00%
# Xceivers: 1
# Last contact: Wed Sep 02 11:17:09 EDT 2020
# Last Block Report: Wed Sep 02 11:16:15 EDT 2020
# Num of Blocks: 0
#
#
# Name: 10.125.2.10:9866 (node0269.palmetto.clemson.edu)
# Hostname: node0269.palmetto.clemson.edu
# Decommission Status : Normal
# Configured Capacity: 182710046720 (170.16 GB)
# DFS Used: 4096 (4 KB)
# Non DFS Used: 6450892800 (6.01 GB)
# DFS Remaining: 176259149824 (164.15 GB)
# DFS Used%: 0.00%
# DFS Remaining%: 96.47%
# Configured Cache Capacity: 0 (0 B)
# Cache Used: 0 (0 B)
# Cache Remaining: 0 (0 B)
# Cache Used%: 100.00%
# Cache Remaining%: 0.00%
# Xceivers: 1
# Last contact: Wed Sep 02 11:17:11 EDT 2020
# Last Block Report: Wed Sep 02 11:16:17 EDT 2020
# Num of Blocks: 0
#
#
# Name: 10.125.2.52:9866 (node0311.palmetto.clemson.edu)
# Hostname: node0311.palmetto.clemson.edu
# Decommission Status : Normal
# Configured Capacity: 182710046720 (170.16 GB)
# DFS Used: 4096 (4 KB)
# Non DFS Used: 3993419776 (3.72 GB)
# DFS Remaining: 178716622848 (166.44 GB)
# DFS Used%: 0.00%
# DFS Remaining%: 97.81%
# Configured Cache Capacity: 0 (0 B)
# Cache Used: 0 (0 B)
# Cache Remaining: 0 (0 B)
# Cache Used%: 100.00%
# Cache Remaining%: 0.00%
# Xceivers: 1
# Last contact: Wed Sep 02 11:17:09 EDT 2020
# Last Block Report: Wed Sep 02 11:16:18 EDT 2020
# Num of Blocks: 0
#
#
# + hdfs --config /home/jin6/hadoop_palmetto/config dfs -mkdir -p /user/jin6/test
# 2020-09-02 11:17:13,139 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# + hdfs --config /home/jin6/hadoop_palmetto/config dfs -ls /user/jin6/test
# 2020-09-02 11:17:16,151 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# + hdfs --config /home/jin6/hadoop_palmetto/config dfs -put /zfs/citi/complete-shakespeare.txt /user/jin6/test/
# 2020-09-02 11:17:19,525 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2020-09-02 11:17:21,123 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# + hdfs --config /home/jin6/hadoop_palmetto/config dfs -ls test/
# 2020-09-02 11:17:23,578 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 1 items
# -rw-r--r--   3 jin6 supergroup    5590193 2020-09-02 11:17 test/complete-shakespeare.txt
# + yarn --config /home/jin6/hadoop_palmetto/config jar /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.2.1.jar wordcount test/complete-shakespeare.txt test_output
# 2020-09-02 11:17:27,086 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2020-09-02 11:17:28,284 INFO client.RMProxy: Connecting to ResourceManager at node2022.palmetto.clemson.edu/10.125.10.159:8050
# 2020-09-02 11:17:28,813 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/jin6/.staging/job_1599059795533_0001
# 2020-09-02 11:17:28,947 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2020-09-02 11:17:29,118 INFO input.FileInputFormat: Total input files to process : 1
# 2020-09-02 11:17:29,176 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2020-09-02 11:17:29,212 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2020-09-02 11:17:29,234 INFO mapreduce.JobSubmitter: number of splits:1
# 2020-09-02 11:17:29,547 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2020-09-02 11:17:29,637 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1599059795533_0001
# 2020-09-02 11:17:29,637 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2020-09-02 11:17:29,913 INFO conf.Configuration: resource-types.xml not found
# 2020-09-02 11:17:29,914 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 2020-09-02 11:17:30,392 INFO impl.YarnClientImpl: Submitted application application_1599059795533_0001
# 2020-09-02 11:17:30,432 INFO mapreduce.Job: The url to track the job: http://node2022.palmetto.clemson.edu:8088/proxy/application_1599059795533_0001/
# 2020-09-02 11:17:30,433 INFO mapreduce.Job: Running job: job_1599059795533_0001
# 2020-09-02 11:17:41,613 INFO mapreduce.Job: Job job_1599059795533_0001 running in uber mode : false
# 2020-09-02 11:17:41,614 INFO mapreduce.Job:  map 0% reduce 0%
# 2020-09-02 11:17:51,755 INFO mapreduce.Job:  map 100% reduce 0%
# 2020-09-02 11:18:00,826 INFO mapreduce.Job:  map 100% reduce 100%
# 2020-09-02 11:18:01,845 INFO mapreduce.Job: Job job_1599059795533_0001 completed successfully
# 2020-09-02 11:18:02,033 INFO mapreduce.Job: Counters: 54
# 	File System Counters
# 		FILE: Number of bytes read=983515
# 		FILE: Number of bytes written=2426309
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=5590339
# 		HDFS: Number of bytes written=721220
# 		HDFS: Number of read operations=8
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 		HDFS: Number of bytes read erasure-coded=0
# 	Job Counters
# 		Launched map tasks=1
# 		Launched reduce tasks=1
# 		Data-local map tasks=1
# 		Total time spent by all maps in occupied slots (ms)=270304
# 		Total time spent by all reduces in occupied slots (ms)=104912
# 		Total time spent by all map tasks (ms)=8447
# 		Total time spent by all reduce tasks (ms)=6557
# 		Total vcore-milliseconds taken by all map tasks=8447
# 		Total vcore-milliseconds taken by all reduce tasks=6557
# 		Total megabyte-milliseconds taken by all map tasks=34598912
# 		Total megabyte-milliseconds taken by all reduce tasks=13428736
# 	Map-Reduce Framework
# 		Map input records=124796
# 		Map output records=904087
# 		Map output bytes=8575070
# 		Map output materialized bytes=983515
# 		Input split bytes=146
# 		Combine input records=904087
# 		Combine output records=67799
# 		Reduce input groups=67799
# 		Reduce shuffle bytes=983515
# 		Reduce input records=67799
# 		Reduce output records=67799
# 		Spilled Records=135598
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=267
# 		CPU time spent (ms)=11570
# 		Physical memory (bytes) snapshot=422449152
# 		Virtual memory (bytes) snapshot=3806859264
# 		Total committed heap usage (bytes)=173211648
# 		Peak Map Physical memory (bytes)=299593728
# 		Peak Map Virtual memory (bytes)=1931325440
# 		Peak Reduce Physical memory (bytes)=122855424
# 		Peak Reduce Virtual memory (bytes)=1875533824
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=5590193
# 	File Output Format Counters
# 		Bytes Written=721220
# + hdfs --config /home/jin6/hadoop_palmetto/config dfs -ls -h test_output
# 2020-09-02 11:18:03,714 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 2 items
# -rw-r--r--   3 jin6 supergroup          0 2020-09-02 11:17 test_output/_SUCCESS
# -rw-r--r--   3 jin6 supergroup    704.3 K 2020-09-02 11:17 test_output/part-r-00000
# + hdfs --config /home/jin6/hadoop_palmetto/config dfs -rm -r test
# 2020-09-02 11:18:07,062 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2020-09-02 11:18:08,663 INFO fs.TrashPolicyDefault: Moved: 'hdfs://node2022.palmetto.clemson.edu:8020/user/jin6/test' to trash at: hdfs://node2022.palmetto.clemson.edu:8020/user/jin6/.Trash/Current/user/jin6/test
# + hdfs --config /home/jin6/hadoop_palmetto/config dfs -rm -r test_output
# 2020-09-02 11:18:10,428 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2020-09-02 11:18:11,739 INFO fs.TrashPolicyDefault: Moved: 'hdfs://node2022.palmetto.clemson.edu:8020/user/jin6/test_output' to trash at: hdfs://node2022.palmetto.clemson.edu:8020/user/jin6/.Trash/Current/user/jin6/test_output

# %% [markdown]
# ## Stop the cluster

# %%
# !./stop_hadoop.sh
# Out:
# Shutting down Hadoop cluster at  node0367.palmetto.clemson.edu
# HADOOP_ROOT: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4
# JAVA_HOME: /software/spackages/linux-centos8-x86_64/gcc-8.3.1/openjdk-1.8.0_222-b10-ui6ldtk7sly7izptgo3yptahiqabz4fd
# + echo 'Begin stopping Hadoop cluster ...'
# Begin stopping Hadoop cluster ...
# + /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/sbin/stop-yarn.sh --config /home/jin6/hadoop_palmetto/config
# WARNING: YARN_CONF_DIR has been replaced by HADOOP_CONF_DIR. Using value of YARN_CONF_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# Stopping nodemanagers
# WARNING: YARN_CONF_DIR has been replaced by HADOOP_CONF_DIR. Using value of YARN_CONF_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# node0367.palmetto.clemson.edu:
# node0367.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0367.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0367.palmetto.clemson.edu:
# node0282.palmetto.clemson.edu:
# node0282.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0282.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0282.palmetto.clemson.edu:
# node0280.palmetto.clemson.edu:
# node0280.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0280.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0280.palmetto.clemson.edu:
# Stopping resourcemanager
# WARNING: YARN_CONF_DIR has been replaced by HADOOP_CONF_DIR. Using value of YARN_CONF_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
#
# real	0m9.449s
# user	0m5.684s
# sys	0m0.772s
# + /software/spackages/linux-centos8-x86_64/gcc-8.3.1/hadoop-3.2.1-lux74iyfcxxzatxh4em67xezesi4z4i4/sbin/stop-dfs.sh --config /home/jin6/hadoop_palmetto/config
# Stopping namenodes on [node0367.palmetto.clemson.edu]
# node0367.palmetto.clemson.edu:
# node0367.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0367.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0367.palmetto.clemson.edu:
# Stopping datanodes
# node0367.palmetto.clemson.edu:
# node0367.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0367.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0367.palmetto.clemson.edu:
# node0280.palmetto.clemson.edu:
# node0280.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0280.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0280.palmetto.clemson.edu:
# node0282.palmetto.clemson.edu:
# node0282.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0282.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0282.palmetto.clemson.edu:
# Stopping secondary namenodes [node0367.palmetto.clemson.edu]
# node0367.palmetto.clemson.edu:
# node0367.palmetto.clemson.edu: The following have been reloaded with a version change:
# node0367.palmetto.clemson.edu:   1) libxml2/2.9.10-gcc/5.4.0 => libxml2/2.9.10-gcc/8.3.1
# node0367.palmetto.clemson.edu:
# 2020-11-04 11:23:52,646 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#
# real	0m19.063s
# user	0m10.889s
# sys	0m1.238s
