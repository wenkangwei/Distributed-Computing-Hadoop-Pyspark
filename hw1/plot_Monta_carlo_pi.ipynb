# %%
import matplotlib.pyplot as plt
elapsed_time = [0.366711, 0.190586, 0.095798, 0.051668, 0.041579]
nprocs = [1,2,4,8,16]
plt.plot(nprocs, elapsed_time,'-o' )
plt.xlabel('number of processor')
plt.ylabel('sec')
plt.legend(["Samples=10,000,000"])
